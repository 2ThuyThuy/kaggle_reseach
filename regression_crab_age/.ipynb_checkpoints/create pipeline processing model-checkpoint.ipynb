# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import StackingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.metrics import mean_absolute_error
SEED = 24

# %%
train_raw = pd.read_csv("train.csv")
test_raw = pd.read_csv("test.csv")

# %%
df_train = train_raw.copy()

# %% [markdown]
# # Processing data

# %% [markdown]
# ## Change name

# %%
df_train.columns = ["id", "sex", "length", "diameter", "height", "weight", "shucked_weight", "viscera_weight", "shell_weight", "age"]

# %%
df_train.head()
# Out:
#    id sex  length  diameter  height     weight  shucked_weight  \
# 0   0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4   I  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    viscera_weight  shell_weight  age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %% [markdown]
# ## Feature engineering
# ### Ratio Features
# - relative size differences between different components

# %%
df_train['shell_ratio'] = df_train['shell_weight'] / df_train['weight']
df_train['shell_to_body_ratio'] = df_train['shell_weight'] / (df_train['weight'] + df_train['shell_weight'])
df_train['meat_yield'] = df_train['shucked_weight'] / (df_train['weight'] + df_train['shell_weight'])
df_train['length_to_dinameter_ratio'] = df_train['length'] / df_train['diameter']
df_train['weight_to_viscera_weight'] = df_train['weight'] / df_train['viscera_weight']
df_train['weight_to_shellWeight_ratio'] = df_train['weight'] / df_train['shell_weight']
df_train['weight_to_shuckedWeight_ratio'] = df_train['weight'] / df_train['shucked_weight']

# %% [markdown]
# ### Geometric Features
# - capture physical properties of the crab

# %%
df_train["surface_area"] = 2*(df_train["length"] * df_train["diameter"] + df_train["length"] * df_train["height"] + df_train["diameter"] * df_train["height"])
df_train["volume"] = df_train["length"]*df_train["diameter"]*df_train["height"]
df_train["density"] = df_train["weight"] / df_train["volume"]
df_train["pseudo_BMI"] = df_train["weight"] / (df_train["height"]**2)

# %% [markdown]
# ### Polynomial features
# capture any non-linear relationship between predictors

# %%
df_train['length_poly'] = df_train['length']**2
df_train['diameter_poly'] = df_train['diameter']**2

# %% [markdown]
# ### Logarithmic Transformations
# - reduce skewness and manage extreme values

# %%
df_train['log_weight'] = l

# %%
math.log(1)
# Out:
# 0.0

# %% [markdown]
# ## One hot data

# %%
df_train = pd.get_dummies(train_raw, columns = ["Sex"])
y = df_train["Age"]
X = df_train.drop(["id","Age"], axis=1)

# %% [markdown]
# ## Split train & test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)

# %% [markdown]
# ## Test with base linear regression model

# %%
def Evaluating_model(y_test, y_pred):
    r2_test = float(format(r2_score(y_test,y_pred),'.3f'))
    RMSE = float(format(mean_squared_error(y_test,y_pred,squared=False),'0.3f'))
    MAE = float(format(mean_absolute_error(y_test, y_pred),'0.3f'))
    return (r2_test, RMSE, MAE)

# %%
base_lr = LinearRegression()
base_lr = base_lr.fit(X_train,y_train)
y_pred = base_lr.predict(X_test)
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# MAE:  1.4824897525481464

# %%
Evaluating_model(y_test, y_pred)
# Out:
# (0.555, 2.137, 1.482)

# %%
def test_model_linear(X, y, name_model, model, Details):
    
    Scalers = [['None',False],['MinMaxScaler',MinMaxScaler()],['StandarScaler',StandardScaler()]]
    
    df_res = pd.DataFrame(index = None, columns =['Model','Details','Scaler','Feature_selection','R_score (train)','R_score (test)',
                                                  'RMSE','MAE','5-Fold Cross Validation'])
    for scaler in Scalers:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)
        
        if scaler[0] != 'None':
            sc = scaler[1].fit(X_train)
            X_train = sc.transform(X_train)
            X_test = sc.transform(X_test)
            
        sum_cols = X.columns.size
        
        for num_cols in range(3,sum_cols+1):
            print('\r', end='')
            print(scaler[0]+': '+str(num_cols)+'/'+str(sum_cols), end='')
            
            kBest = SelectKBest(f_regression,k = num_cols)
            kBest.fit(X_train, y_train)
            
            X_train_KBest = kBest.transform(X_train)
            X_test_KBest = kBest.transform(X_test)
           
            mod = model
            mod = model.fit(X_train_KBest, y_train)
            
            y_pred = mod.predict(X_test_KBest)
        
            r2_train = r2_score(y_train, mod.predict(X_train_KBest))
            r2_test, RMSE, MAE = Evaluating_model(y_test, y_pred)
            fcv = float(format(cross_val_score(mod, X_test, y_test).mean(),'.3f'))
            df_res = df_res.append(pd.Series({'Model':name_model,
                                              'Details':Details,
                                              'Scaler':scaler[0],
                                              'Feature_selection':num_cols,
                                              'R_score (train)':r2_train,
                                              'R_score (test)':r2_test,
                                              'RMSE':RMSE,'MAE':MAE,
                                              '5-Fold Cross Validation':fcv
                                             }),ignore_index = True)
    return df_res

# %%
df_lr =  test_model_linear(X, y, "LinearRegression",LinearRegression(), "")
# Out:
# StandarScaler: 10/10

# %%
df_lr.sort_values(by= ["MAE"])
# Out:
#                Model Details         Scaler Feature_selection  \
# 23  LinearRegression          StandarScaler                10
# 6   LinearRegression                   None                 9
# 7   LinearRegression                   None                10
# 15  LinearRegression           MinMaxScaler                10
# 14  LinearRegression           MinMaxScaler                 9
# 22  LinearRegression          StandarScaler                 9
# 21  LinearRegression          StandarScaler                 8
# 5   LinearRegression                   None                 8
# 13  LinearRegression           MinMaxScaler                 8
# 20  LinearRegression          StandarScaler                 7
# 4   LinearRegression                   None                 7
# 12  LinearRegression           MinMaxScaler                 7
# 19  LinearRegression          StandarScaler                 6
# 18  LinearRegression          StandarScaler                 5
# 11  LinearRegression           MinMaxScaler                 6
# 3   LinearRegression                   None                 6
# 2   LinearRegression                   None                 5
# 10  LinearRegression           MinMaxScaler                 5
# 9   LinearRegression           MinMaxScaler                 4
# 17  LinearRegression          StandarScaler                 4
# 1   LinearRegression                   None                 4
# 16  LinearRegression          StandarScaler                 3
# 8   LinearRegression           MinMaxScaler                 3
# 0   LinearRegression                   None                 3
#
#     R_score (train)  R_score (test)   RMSE    MAE  5-Fold Cross Validation
# 23         0.549686           0.555  2.137  1.482                    0.555
# 6          0.549688           0.555  2.137  1.482                    0.555
# 7          0.549688           0.555  2.137  1.482                    0.555
# 15         0.549685           0.555  2.137  1.482                    0.555
# 14         0.549688           0.555  2.137  1.482                    0.555
# 22         0.549688           0.555  2.137  1.482                    0.555
# 21         0.549444           0.555  2.137  1.483                    0.555
# 5          0.549444           0.555  2.137  1.483                    0.555
# 13         0.549444           0.555  2.137  1.483                    0.555
# 20         0.498061           0.499  2.268  1.571                    0.555
# 4          0.498061           0.499  2.268  1.571                    0.555
# 12         0.498061           0.499  2.268  1.571                    0.555
# 19         0.484209           0.486  2.298  1.598                    0.555
# 18         0.483635           0.485  2.300  1.598                    0.555
# 11         0.484209           0.486  2.298  1.598                    0.555
# 3          0.484209           0.486  2.298  1.598                    0.555
# 2          0.483635           0.485  2.300  1.598                    0.555
# 10         0.483635           0.485  2.300  1.598                    0.555
# 9          0.450338           0.452  2.372  1.661                    0.555
# 17         0.450338           0.452  2.372  1.661                    0.555
# 1          0.450338           0.452  2.372  1.661                    0.555
# 16         0.448855           0.450  2.376  1.664                    0.555
# 8          0.448855           0.450  2.376  1.664                    0.555
# 0          0.448855           0.450  2.376  1.664                    0.555

# %% [markdown]
# # Feature engineering

# %%
df_train
# Out:
#           id  Length  Diameter  Height     Weight  Shucked Weight  \
# 0          0  1.5250    1.1750  0.3750  28.973189       12.728926
# 1          1  1.1000    0.8250  0.2750  10.418441        4.521745
# 2          2  1.3875    1.1125  0.3750  24.777463       11.339800
# 3          3  1.7000    1.4125  0.5000  50.660556       20.354941
# 4          4  1.2500    1.0125  0.3375  23.289114       11.977664
# ...      ...     ...       ...     ...        ...             ...
# 74046  74046  1.6625    1.2625  0.4375  50.660556       20.680960
# 74047  74047  1.0750    0.8625  0.2750  10.446791        4.323299
# 74048  74048  1.4875    1.2000  0.4125  29.483480       12.303683
# 74049  74049  1.2125    0.9625  0.3125  16.768729        8.972617
# 74050  74050  0.9125    0.6750  0.2000   5.386405        2.055339
#
#        Viscera Weight  Shell Weight  Age  Sex_F  Sex_I  Sex_M
# 0            6.647958      8.348928    9      0      1      0
# 1            2.324659      3.401940    8      0      1      0
# 2            5.556502      6.662133    9      0      0      1
# 3           10.991839     14.996885   11      1      0      0
# 4            4.507570      5.953395    8      0      1      0
# ...               ...           ...  ...    ...    ...    ...
# 74046       10.361742     12.332033   10      1      0      0
# 74047        2.296310      3.543687    6      0      1      0
# 74048        7.540967      8.079607   10      1      0      0
# 74049        2.919999      4.280774    8      0      1      0
# 74050        1.034757      1.700970    6      0      1      0
#
# [74051 rows x 12 columns]

# %% [markdown]
# # Build piple model

# %%
def test_model(X, y, name_model, model, Details):
    
    Scalers = [['None',False],['MinMaxScaler',MinMaxScaler()],['StandarScaler',StandardScaler()]]
    
    df_res = pd.DataFrame(index = None, columns =['Model','Details','Scaler','Feature_selection','R_score (train)','R_score (test)',
                                              'RMSE','MAE','5-Fold Cross Validation'])
    
    summ = 8 # print %%%%
    i = 0
    for scaler in Scalers:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)
        
        if scaler[0] != 'None':
            sc = scaler[1].fit(X_train)
            X_train = sc.transform(X_train)
            X_test = sc.transform(X_test)
            
            
        sum_cols = X.columns.size
        
        lis_features = [8,9, 10]
        for num_cols in lis_features:
            print('\r', end='')
            print('{:.3f}'.format((i/summ)*100),'% ', end='')
            i+=1
            
            
            kBest = SelectKBest(f_regression,k = num_cols)
            kBest.fit(X_train, y_train)
            
            X_train_KBest = kBest.transform(X_train)
            X_test_KBest = kBest.transform(X_test)
           
            mod = model
            mod = model.fit(X_train_KBest, y_train)
            
            y_pred = mod.predict(X_test_KBest)
        
            r2_train = r2_score(y_train, mod.predict(X_train_KBest))
            r2_test, RMSE, MAE = Evaluating_model(y_test, y_pred)
            fcv = float(format(cross_val_score(mod, X_test, y_test).mean(),'.3f'))
            df_res = df_res.append(pd.Series({'Model':name_model,
                                              'Details':Details,
                                              'Scaler':scaler[0],
                                              'Feature_selection':num_cols,
                                              'R_score (train)':r2_train,
                                              'R_score (test)':r2_test,
                                              'RMSE':RMSE,'MAE':MAE,
                                              '5-Fold Cross Validation':fcv
                                             }),ignore_index = True)
    return df_res

# %% [markdown]
# ## KNeighbors

# %%
df_KNR_0 = test_model(X, y,'KNeighbors Regressor',KNeighborsRegressor(),'None')
# Out:
# 88.889 %

# %%
df_SVR_0.sort_values(by = ["MAE"])

# %% [markdown]
# ## Decistion Tree Regressor

# %%
df_DTR_0 = test_model(X.copy(), y.copy(),'Decision Tree Regressor', DecisionTreeRegressor(max_depth  = 10, min_samples_split=5, random_state = SEED),'None')
# Out:
# 100.000 %

# %%
df_DTR_0.sort_values(by = ["MAE"]).head()
# Out:
#                      Model Details         Scaler Feature_selection  \
# 0  Decision Tree Regressor    None           None                 8
# 3  Decision Tree Regressor    None   MinMaxScaler                 8
# 2  Decision Tree Regressor    None           None                10
# 5  Decision Tree Regressor    None   MinMaxScaler                10
# 6  Decision Tree Regressor    None  StandarScaler                 8
#
#    R_score (train)  R_score (test)   RMSE    MAE  5-Fold Cross Validation
# 0         0.621293           0.543  2.167  1.467                    0.432
# 3         0.621293           0.542  2.168  1.467                    0.433
# 2         0.621774           0.541  2.170  1.468                    0.432
# 5         0.621774           0.542  2.169  1.468                    0.433
# 6         0.621293           0.542  2.169  1.468                    0.432

# %% [markdown]
# ## Random Forest Regression

# %%
df_RFR_0 = test_model(X.copy(), y.copy(),'Random Forest Regressor',
                    RandomForestRegressor(random_state = SEED),'None')
# Out:
# 88.889 %

# %%
df_RFR_0.sort_values(by = ["MAE"]).head()
# Out:
#                      Model Details         Scaler Feature_selection  \
# 1  Random Forest Regressor    None           None                 9
# 2  Random Forest Regressor    None           None                10
# 4  Random Forest Regressor    None   MinMaxScaler                 9
# 5  Random Forest Regressor    None   MinMaxScaler                10
# 7  Random Forest Regressor    None  StandarScaler                 9
#
#    R_score (train)  R_score (test)   RMSE    MAE  5-Fold Cross Validation
# 1         0.938392           0.558  2.130  1.474                    0.548
# 2         0.938415           0.558  2.130  1.475                    0.548
# 4         0.938394           0.558  2.131  1.475                    0.548
# 5         0.938406           0.558  2.131  1.475                    0.548
# 7         0.938415           0.558  2.131  1.475                    0.548

# %% [markdown]
# ## linear SVR

# %%
df_SVR_0 = test_model(X.copy(), y.copy(),'LinearSVR',
                    LinearSVR(random_state = SEED),"None")
# Out:
# 0.000 %
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 12.500 %
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 25.000 %
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# C:\Users\boot.AI\anaconda3\envs\deep_learning\lib\site-packages\sklearn\svm\_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# 100.000 %

# %%
df_SVR_0.sort_values(by = ["MAE"]).head()
# Out:
#        Model Details         Scaler Feature_selection  R_score (train)  \
# 6  LinearSVR    None  StandarScaler                 8         0.527697
# 7  LinearSVR    None  StandarScaler                 9         0.527515
# 8  LinearSVR    None  StandarScaler                10         0.527120
# 1  LinearSVR    None           None                 9         0.527317
# 3  LinearSVR    None   MinMaxScaler                 8         0.524151
#
#    R_score (test)   RMSE    MAE  5-Fold Cross Validation
# 6           0.530  2.196  1.449                    0.534
# 7           0.530  2.197  1.449                    0.534
# 8           0.529  2.198  1.449                    0.534
# 1           0.530  2.198  1.451                    0.474
# 3           0.526  2.207  1.451                    0.521

# %% [markdown]
# ## GradientBoostingRegressor

# %%
df_GBR_0 = test_model(X.copy(), y.copy(),'GradientBoostingRegressor',
                    GradientBoostingRegressor(random_state = SEED),'None')
# Out:
# 88.889 %

# %%
df_GBR_0.sort_values(by = ["MAE"]).head()
# Out:
#                        Model Details         Scaler Feature_selection  \
# 1  GradientBoostingRegressor    None           None                 9
# 2  GradientBoostingRegressor    None           None                10
# 4  GradientBoostingRegressor    None   MinMaxScaler                 9
# 5  GradientBoostingRegressor    None   MinMaxScaler                10
# 7  GradientBoostingRegressor    None  StandarScaler                 9
#
#    R_score (train)  R_score (test)   RMSE    MAE  5-Fold Cross Validation
# 1         0.585979           0.577  2.085  1.429                    0.569
# 2         0.585978           0.577  2.085  1.429                    0.569
# 4         0.585979           0.577  2.085  1.429                    0.569
# 5         0.585978           0.577  2.085  1.429                    0.569
# 7         0.585979           0.577  2.085  1.429                    0.569

# %% [markdown]
# ## Gen submission

# %%
def gen_submission(model):
    
    df_sub = test_raw["id"].to_frame()
    
    ## processing
    df_test = pd.get_dummies(test_raw, columns = ["Sex"])
    df_test.drop(["id"], axis=1, inplace=True)
    
    ## gen file 
    pred = base_lr.predict(df_test)
    df_sub["Age"] = pred
    df_sub.to_csv("submission_crab.csv", index =False)

# %%
gen_submission(base_lr)
